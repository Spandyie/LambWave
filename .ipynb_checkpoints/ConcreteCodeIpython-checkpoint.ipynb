# %%
from scipy.io import loadmat
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
# %matplotlib notebook

data=[]
TestData=[]
FileNames= glob.glob("*.mat") #  # loading data 1
TestFileName=glob.glob("testData/*.mat") # loading data 2

[data.append(loadmat(f,squeeze_me=True, struct_as_record=False)) for f in FileNames]  #loading all the data in the file
[TestData.append(loadmat(f,squeeze_me=True, struct_as_record=False)) for f in TestFileName]
# Out:
# [None, None, None, None, None]

# %% [markdown]
# The length of actuator signal is equals to length of the cross talk, we will use actuator signal length to zero pad the actuator signal. Frequency of actuation and sampling rate can be obtained as:

# %%
frequency=data[0]['setup'].signal_definition.frequency1
# sampling rate of the signal
sampling_rate=data[0]['setup'].sampling_rate

# %% [markdown]
# Now that we know the sampling frequency and driving frequency of the signal. The cross talk in the sensor signal will be zeropadded with length equal to length of the 5 cycle burst of actuator signal.

# %%
crosstalk=[]
frequency=[]
sampling_rate=[]
for signals in data:
    frequency.append(signals['setup'].signal_definition.frequency1)
    sampling_rate.append(signals['setup'].sampling_rate)
    crosstalk.append(5/(signals['setup'].signal_definition.frequency1)* (signals['setup'].sampling_rate))

# %%
for i in range(5):
    data[i]['s0'][1:int(crosstalk[i])]=0  #training data
    TestData[i]['s0'][1:int(crosstalk[i])]=0  # test data
    
SensorData=list()
ActuatorData=list()

[SensorData.append(signal['s0']) for signal in data ]  # sensor data arranged in list
[ActuatorData.append(signal['a0']) for signal in data]  # Actuator data arrange in list

TestSensorData=list()
TestActuatorData=list()

[TestSensorData.append(signal['s0']) for signal in TestData ]  # Test data  for sensor  arranged in list
[TestActuatorData.append(signal['a0']) for signal in TestData]  # test data for actuator  arrange in list
# Out:
# [None, None, None, None, None]

# %%
def DynamicTimeWarping(x,y):
    DTW={}
    len1=len(x)
    len2=len(y)
    for i in range(len1):
        DTW[(i,-1)]=float('inf')
    
    for j in range(len2):
        DTW[(-1,j)]=float('inf')
    DTW[(-1,-1)]=0
    for i in range(len1):
        for j in range(len2):
            
            DistTemp= (x[i]-y[j])**2
            DTW[(i,j)]= DistTemp + min(DTW[(i-1,j-1)], DTW[(i-1,j)], DTW[(i,j-1)])
    return(DTW[(len1-1,len2-1)])

# %% [markdown]
# We will use Keras to  code sparse encoder to extract feature from LambWaves.

# %%
########################
TotalData=SensorData+TestSensorData
TotalData=np.asarray(TotalData)
#####################################
#####################################
from keras.layers import Input, Dense
from keras.models import Model
#from keras.optimizers import Adam
from keras import regularizers

np.random.seed(7)
SensorData=np.asarray(SensorData) # converting list into array (training data)
TestSensorData=  np.asarray(TestSensorData)
InputSignal=SensorData[0]
actual_signal_len=len(InputSignal)
encoding_dim=100 # This going to be size of our encoded representation
#this returns a tensor
inputs = Input(shape=(actual_signal_len,))
encoded=Dense(encoding_dim,activation='relu',activity_regularizer=regularizers.l1(10e-5))(inputs)
decoded=Dense(actual_signal_len)(encoded)

# this model maps an input to its encoded representation
encoder = Model(input=inputs, output=encoded)

## this model maps an input to its reconstruction
autoencoder= Model(input = inputs, output= decoded)
#we'll configure our model to use a mean squarred error loss, and the Adam optimizer
# we also train autoencoder for 50 epochs
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.fit(TotalData, TotalData, epochs=100, batch_size=1)

#######################
#Encode the images
encoded_signal= encoder.predict(SensorData)
EncodedTestData= encoder.predict(TestSensorData)
# Out:
# c:\miniconda3\lib\site-packages\ipykernel\__main__.py:23: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# c:\miniconda3\lib\site-packages\ipykernel\__main__.py:26: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# Epoch 1/50
# 10/10 [==============================] - 1s - loss: 159.8511
# Epoch 2/50
# 10/10 [==============================] - 0s - loss: 101.7649
# Epoch 3/50
# 10/10 [==============================] - 0s - loss: 36.3315
# Epoch 4/50
# 10/10 [==============================] - 0s - loss: 13.3895
# Epoch 5/50
# 10/10 [==============================] - 0s - loss: 7.5405
# Epoch 6/50
# 10/10 [==============================] - 0s - loss: 5.7474
# Epoch 7/50
# 10/10 [==============================] - 0s - loss: 5.6287
# Epoch 8/50
# 10/10 [==============================] - 0s - loss: 5.0217
# Epoch 9/50
# 10/10 [==============================] - 0s - loss: 4.2118
# Epoch 10/50
# 10/10 [==============================] - 0s - loss: 5.4837
# Epoch 11/50
# 10/10 [==============================] - 0s - loss: 12.0617
# Epoch 12/50
# 10/10 [==============================] - 0s - loss: 11.6493
# Epoch 13/50
# 10/10 [==============================] - 0s - loss: 11.2805
# Epoch 14/50
# 10/10 [==============================] - 0s - loss: 8.0212
# Epoch 15/50
# 10/10 [==============================] - 0s - loss: 4.2007
# Epoch 16/50
# 10/10 [==============================] - 0s - loss: 3.0493
# Epoch 17/50
# 10/10 [==============================] - 0s - loss: 2.6240
# Epoch 18/50
# 10/10 [==============================] - 0s - loss: 2.3505
# Epoch 19/50
# 10/10 [==============================] - 0s - loss: 2.4459
# Epoch 20/50
# 10/10 [==============================] - 0s - loss: 2.6175
# Epoch 21/50
# 10/10 [==============================] - 0s - loss: 3.3171
# Epoch 22/50
# 10/10 [==============================] - 0s - loss: 3.2647
# Epoch 23/50
# 10/10 [==============================] - 0s - loss: 2.3183
# Epoch 24/50
# 10/10 [==============================] - 0s - loss: 2.1428
# Epoch 25/50
# 10/10 [==============================] - 0s - loss: 2.3760
# Epoch 26/50
# 10/10 [==============================] - 0s - loss: 1.9022
# Epoch 27/50
# 10/10 [==============================] - 0s - loss: 2.0359
# Epoch 28/50
# 10/10 [==============================] - 0s - loss: 1.9699
# Epoch 29/50
# 10/10 [==============================] - 0s - loss: 2.0127
# Epoch 30/50
# 10/10 [==============================] - 0s - loss: 1.9047
# Epoch 31/50
# 10/10 [==============================] - 0s - loss: 1.7676
# Epoch 32/50
# 10/10 [==============================] - 0s - loss: 1.9278
# Epoch 33/50
# 10/10 [==============================] - 0s - loss: 2.6854
# Epoch 34/50
# 10/10 [==============================] - 0s - loss: 2.3000
# Epoch 35/50
# 10/10 [==============================] - 0s - loss: 1.9604
# Epoch 36/50
# 10/10 [==============================] - 0s - loss: 2.4745
# Epoch 37/50
# 10/10 [==============================] - 0s - loss: 2.7982
# Epoch 38/50
# 10/10 [==============================] - 0s - loss: 3.3074
# Epoch 39/50
# 10/10 [==============================] - 0s - loss: 3.0384
# Epoch 40/50
# 10/10 [==============================] - 0s - loss: 6.5894
# Epoch 41/50
# 10/10 [==============================] - 0s - loss: 5.4260
# Epoch 42/50
# 10/10 [==============================] - 0s - loss: 5.0669
# Epoch 43/50
# 10/10 [==============================] - 0s - loss: 8.9694
# Epoch 44/50
# 10/10 [==============================] - 0s - loss: 3.8350
# Epoch 45/50
# 10/10 [==============================] - 0s - loss: 2.7492
# Epoch 46/50
# 10/10 [==============================] - 0s - loss: 2.9257
# Epoch 47/50
# 10/10 [==============================] - 0s - loss: 2.5553
# Epoch 48/50
# 10/10 [==============================] - 0s - loss: 2.3896
# Epoch 49/50
# 10/10 [==============================] - 0s - loss: 1.8972
# Epoch 50/50
# 10/10 [==============================] - 0s - loss: 2.2043

# %% [markdown]
# In the above code we trained an sparse autoencoder for 100 epochs, the encoded signals "*encoded_signal* " and the *gaps*, variable will be fitted in a linear regression. The figures below show the encoded training signals *encoded_signal* and *EncodedTestData*.

# %%
from matplotlib.pyplot import cm
c=cm.rainbow(np.linspace(0,1,5))
labels=['no gap','0.2 mm gap','0.3 mm gap','0.4 mm gap','0.1 mm gap']
#%matplotlib notebook
plt.figure()
for c,signal,l in zip(c,encoded_signal,labels):
    plt.plot(signal,color=c,label=l)
plt.xlabel('Sampling Number')
plt.ylabel('Volts')
plt.legend()
# Out:
# <img src="data:image/png;base64,...">

# %%
c=cm.rainbow(np.linspace(0,1,5))
labels=['no gap','0.2 mm gap','0.3 mm gap','0.4 mm gap','0.1 mm gap']
#%matplotlib notebook
plt.figure()
for c,signal,l in zip(c,EncodedTestData,labels):
    plt.plot(signal,color=c,label=l)

plt.xlabel('Sampling Number')
plt.ylabel('Volts')
plt.legend()
plt.title("Test Data")
# Out:
# <img src="data:image/png;base64,...">

# %%
#DynamicWarp=[]
#DynamicWarpTest=[]
#[DynamicWarp.append(DynamicTimeWarping(encoded_signal[0],signal)) for signal in encoded_signal]
#[DynamicWarpTest.append(DynamicTimeWarping(EncodedTestData[0],signal)) for signal in EncodedTestData]
#gaps=[0,0.2,0.3,0.4,0.1]

# %% [markdown]
# Considering "0" mm as a baseline data we estimate the Euclidean distance between encoded signals. *dist1* will be used as training data to fit the linear regression. Similalry, *dist2* will be used to validate the model.

# %%
dist1=[]
dist2=[]
for x,y in zip(encoded_signal,EncodedTestData):
    dist1.append(np.linalg.norm(encoded_signal[0]-x))
    dist2.append(np.linalg.norm(EncodedTestData[0]-y))

# %%
from sklearn import linear_model
gaps=[0,0.2,0.3,0.4,0.1]
gaps=np.asarray(gaps)
dist1=np.asarray(dist1)
dist2=np.asarray(dist2)
#lets create a regression object
regr= linear_model.LinearRegression(fit_intercept=True,normalize=True)
#fitting the linear regression
regr.fit(dist1.reshape(5,1),gaps.reshape(5,1))
print("The regression coefficients are as:[%.7f, %.7f]" % (regr.intercept_ ,  regr.coef_))
# The final prediction of the test data
TrainingGaps=regr.predict(dist1.reshape(5,1))
PredictionGaps=regr.predict(dist2.reshape(5,1))
# Out:
# The regression coefficients are as:[-0.0241117, 0.0023210]

# %% [markdown]
# Now lets do a predicted v/s actual plot for predicted data sets.

# %%
fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.scatter(gaps,TrainingGaps,s=20,c='red',marker='s',label='Training Data Predictions')
ax1.scatter(gaps,PredictionGaps,s=20,c='black',marker='o',label='Test Data prediction')
plt.xlabel('Actual Gap')
plt.ylabel('Predicted Gap')
plt.legend(loc='upper left');
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# The figure below displays the relationship between gaps and damage metric (Euclidean distance betweeen encoded signals)

# %%
plt.figure()
plt.scatter(dist1,gaps,s=20,c='red',marker='s')
plt.xlabel('Euclidean distance between two signal')
plt.ylabel('Gaps')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
